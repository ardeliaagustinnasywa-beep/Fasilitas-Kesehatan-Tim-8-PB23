# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
# Memuat Data Set
df = pd.read_csv("fasilitas2024.csv")

# %%
df.head(28)
# Out:
#              NAMA KABUPATEN  JUMLAH RUMAH SAKIT  JUMLAH PUSKESMAS  \
# 0           KABUPATEN BOGOR                  31               258
# 1        KABUPATEN SUKABUMI                   9               282
# 2         KABUPATEN CIANJUR                   7               157
# 3         KABUPATEN BANDUNG                  17               100
# 4           KABUPATEN GARUT                   9               276
# 5     KABUPATEN TASIKMALAYA                   3               200
# 6          KABUPATEN CIAMIS                   6               185
# 7        KABUPATEN KUNINGAN                  12               152
# 8         KABUPATEN CIREBON                  13               129
# 9      KABUPATEN MAJALENGKA                   6               126
# 10       KABUPATEN SUMEDANG                   5               115
# 11      KABUPATEN INDRAMAYU                  12               117
# 12         KABUPATEN SUBANG                  11               143
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("fasilitas2024.csv")

# Mengambil total fasilitas kesehatan di seluruh Jawa Barat
faskes_data = {
    'Rumah Sakit': df['JUMLAH RUMAH SAKIT'].sum(),
    'Puskesmas': df['JUMLAH PUSKESMAS'].sum(),
    'Posyandu': df['JUMLAH POSYANDU'].sum(),
    'Apotek': df['JUMLAH APOTEK'].sum(),
    'Klinik': df['JUMLAH KLINIK'].sum()
}

# Membuat pie chart
plt.figure(figsize=(8,8))
plt.pie(
    faskes_data.values(),
    labels=faskes_data.keys(),
    autopct='%1.1f%%',
    startangle=90
)

plt.title("Distribusi Fasilitas Kesehatan di Jawa Barat")
plt.show()

# %%
# Ubah data dari format wide ke long (supaya bisa dibuat boxplot)
df_long = df.melt(
    id_vars=['NAMA KABUPATEN'], 
    value_vars=[
        'JUMLAH RUMAH SAKIT',
        'JUMLAH PUSKESMAS',
        'JUMLAH POSYANDU',
        'JUMLAH APOTEK',
        'JUMLAH KLINIK'
    ],
    var_name='Kategori_Fasilitas',
    value_name='Jumlah_Fasilitas'
)

# Plot boxplot
sns.boxplot(
    data=df_long,
    x='Kategori_Fasilitas',
    y='Jumlah_Fasilitas'
)

plt.title("Distribusi Jumlah Fasilitas Kesehatan di Jawa Barat")
plt.xlabel("Kategori Fasilitas")
plt.ylabel("Jumlah")
plt.xticks(rotation=30)
plt.show()

# %%
# Jumlah Rumah Sakit
plt.figure(figsize=(14,5))
sns.barplot(
    data=df,
    x='NAMA KABUPATEN',
    y='JUMLAH RUMAH SAKIT',
    estimator=sum,
    palette='Blues'
)
plt.title("Jumlah Rumah Sakit di Jawa Barat")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_10648\414076709.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# Jumlah Puskesmas
plt.figure(figsize=(14,5))
sns.barplot(
    data=df,
    x='NAMA KABUPATEN',
    y='JUMLAH PUSKESMAS',
    estimator=sum,
    palette='Blues'
)
plt.title("Jumlah Puskesmas di Jawa Barat")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_10648\959280454.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# Jumlah Posyandu
plt.figure(figsize=(14,5))
sns.barplot(
    data=df,
    x='NAMA KABUPATEN',
    y='JUMLAH POSYANDU',
    estimator=sum,
    palette='Blues'
)
plt.title("Jumlah Posyandu di Jawa Barat")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_10648\1625639834.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# Jumlah Apotek
plt.figure(figsize=(14,5))
sns.barplot(
    data=df,
    x='NAMA KABUPATEN',
    y='JUMLAH APOTEK',
    estimator=sum,
    palette='Blues'
)
plt.title("Jumlah Apotek di Jawa Barat")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_10648\1577635944.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# Jumlah Klinik
plt.figure(figsize=(14,5))
sns.barplot(
    data=df,
    x='NAMA KABUPATEN',
    y='JUMLAH KLINIK',
    estimator=sum,
    palette='Blues'
)
plt.title("Jumlah Klinik di Jawa Barat")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_10648\1963857015.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# Ubah data dari wide ➜ long
df_long = df.melt(
    id_vars=['NAMA KABUPATEN'],
    value_vars=[
        'JUMLAH RUMAH SAKIT',
        'JUMLAH PUSKESMAS',
        'JUMLAH POSYANDU',
        'JUMLAH APOTEK',
        'JUMLAH KLINIK'
    ],
    var_name='Kategori_Fasilitas',
    value_name='Jumlah'
)

# Plot grouped barplot
plt.figure(figsize=(12,6))
sns.barplot(
    data=df_long,
    x='NAMA KABUPATEN',
    y='Jumlah',
    hue='Kategori_Fasilitas',
    palette='pastel'
)

plt.title("Jumlah Fasilitas Kesehatan di Jawa Barat")
plt.xlabel("Kabupaten / Kota")
plt.ylabel("Jumlah Fasilitas")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Histogram Jumlah Rumah Sakit
sns.histplot(
    df['JUMLAH RUMAH SAKIT'],
    kde=True,
    bins=15
)

plt.title("Distribusi Jumlah Rumah Sakit di Jawa Barat")
plt.xlabel("Jumlah Rumah Sakit")
plt.ylabel("Frekuensi Kabupaten/Kota")
plt.show()

# %%
# Histogram Jumlah Puskesmas
sns.histplot(
    df['JUMLAH PUSKESMAS'],
    kde=True,
    bins=15
)
plt.title("Distribusi Jumlah Puskesmas di Jawa Barat")
plt.xlabel("Jumlah Puskesmas")
plt.ylabel("Frekuensi Kabupaten/Kota")
plt.show()

# %%
# Histogram Jumlah Posyandu
sns.histplot(
    df['JUMLAH POSYANDU'],
    kde=True,
    bins=15
)
plt.title("Distribusi Jumlah Posyandu di Jawa Barat")
plt.xlabel("Jumlah Posyandu")
plt.ylabel("Frekuensi Kabupaten/Kota")
plt.show()

# %%
# Histogram Jumlah Apotek
sns.histplot(
    df['JUMLAH APOTEK'],
    kde=True,
    bins=15
)
plt.title("Distribusi Jumlah Apotek di Jawa Barat")
plt.xlabel("Jumlah Apotek")
plt.ylabel("Frekuensi Kabupaten/Kota")
plt.show()

# %%
# Histogram Jumlah Klinik
sns.histplot(
    df['JUMLAH KLINIK'],
    kde=True,
    bins=15
)
plt.title("Distribusi Jumlah Klinik di Jawa Barat")
plt.xlabel("Jumlah Klinik")
plt.ylabel("Frekuensi Kabupaten/Kota")
plt.show()

# %%
# Memilih fitur untuk clustering sesuai data fasilitas kesehatan
features = [
    'JUMLAH RUMAH SAKIT',
    'JUMLAH PUSKESMAS',
    'JUMLAH POSYANDU',
    'JUMLAH APOTEK',
    'JUMLAH KLINIK'
]

# %%
# Standardisasi data sesuai kolom fasilitas kesehatan
scaler = StandardScaler()
scaled_features = scaler.fit_transform(df[
    ['JUMLAH RUMAH SAKIT',
     'JUMLAH PUSKESMAS',
     'JUMLAH POSYANDU',
     'JUMLAH APOTEK',
     'JUMLAH KLINIK']
])

# %%
# Menentukan jumlah cluster menggunakan metode Elbow
inertia = []
k_values = range(1, 11)

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init='auto')
    kmeans.fit(scaled_features)   # <-- sudah memakai fasilitas kesehatan
    inertia.append(kmeans.inertia_)

# %%
# Plot Elbow Method menggunakan data fasilitas kesehatan
plt.figure(figsize=(8, 5))
plt.plot(k_values, inertia, marker='o')
plt.title("Elbow Method untuk Menentukan Jumlah Cluster Optimal (Data Fasilitas Kesehatan)")
plt.xlabel("Jumlah Cluster (k)")
plt.ylabel("Inertia")
plt.grid()
plt.show()

# %%
# Menggunakan jumlah cluster optimal
optimal_k = 4 # Berdasarkan elbow method 
kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init='auto')
df['cluster'] = kmeans.fit_predict(scaled_features)

# %%
# Mengurangi dimensi data untuk visualisasi 
pca = PCA(n_components=2)
reduced_features = pca.fit_transform(scaled_features)

# %%
colors = ['red', 'blue', 'green', 'purple']

# %%
# Pastikan cluster disimpan 
df['cluster'] = kmeans.fit_predict(scaled_features)

# Plot PCA clustering (versi fasilitas kesehatan)
plt.figure(figsize=(10, 7))

for cluster in range(optimal_k):
    cluster_points = reduced_features[df['cluster'] == cluster]

    plt.scatter(
        cluster_points[:, 0],
        cluster_points[:, 1],
        s=50,
        label=f'Cluster {cluster}',
        color=colors[cluster]
    )

# Hitung posisi centroid dalam ruang PCA
centroids_reduced = pca.transform(kmeans.cluster_centers_)

plt.scatter(
    centroids_reduced[:, 0],
    centroids_reduced[:, 1],
    s=200,
    c='black',
    marker='X',
    label='Centroids'
)

plt.title("Clustering K-Means Fasilitas Kesehatan (PCA 2D)")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.grid()
plt.legend()
plt.show()
